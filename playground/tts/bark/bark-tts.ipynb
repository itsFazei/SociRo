# %% [markdown]
# # TTS Bark playground

# %% [markdown]
# > Make sure to have an assigned venv for this specific model!
#
# This notebook wil contain all the experiments and documentations regarding the [Bark](https://github.com/suno-ai/bark) model.
